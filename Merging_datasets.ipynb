# %%
import pandas as pd

# %%
df = pd.read_csv('./StormEvents_details_2022.csv')
df.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202202         20        2118         202202       20      2218
# 1           202202         21         800         202202       22      1000
# 2           202202         22         200         202202       22       900
# 3           202202         18        1609         202202       18      1609
# 4           202202          2           0         202202        3         0
#
#    EPISODE_ID  EVENT_ID           STATE  STATE_FIPS  ...  END_RANGE  \
# 0      165464    999902          NEVADA          32  ...        NaN
# 1      165465    999903          NEVADA          32  ...        NaN
# 2      165465    999904          NEVADA          32  ...        NaN
# 3      165611   1001181  ATLANTIC SOUTH          87  ...        7.0
# 4      165668   1001527  AMERICAN SAMOA          97  ...        5.0
#
#   END_AZIMUTH END_LOCATION BEGIN_LAT  BEGIN_LON  END_LAT   END_LON  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69477 entries, 0 to 69476
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     69477 non-null  int64
#  1   BEGIN_DAY           69477 non-null  int64
#  2   BEGIN_TIME          69477 non-null  int64
#  3   END_YEARMONTH       69477 non-null  int64
#  4   END_DAY             69477 non-null  int64
#  5   END_TIME            69477 non-null  int64
#  6   EPISODE_ID          69477 non-null  int64
#  7   EVENT_ID            69477 non-null  int64
#  8   STATE               69477 non-null  object
#  9   STATE_FIPS          69477 non-null  int64
#  10  YEAR                69477 non-null  int64
#  11  MONTH_NAME          69477 non-null  object
#  12  EVENT_TYPE          69477 non-null  object
#  13  CZ_TYPE             69477 non-null  object
#  14  CZ_FIPS             69477 non-null  int64
# ...

# %%
df2 = pd.read_csv('./StormEvents_fatalities_2022.csv')
df2.head()
# Out:
#    FAT_YEARMONTH  FAT_DAY  FAT_TIME  FATALITY_ID  EVENT_ID FATALITY_TYPE  \
# 0         202202        2         0        45421    995493             I
# 1         202202        2         0        45422    995493             I
# 2         202202        2         0        45423    995500             I
# 3         202202        2         0        45424    995524             I
# 4         202202       17         0        46159   1000649             D
#
#          FATALITY_DATE  FATALITY_AGE FATALITY_SEX      FATALITY_LOCATION  \
# 0  02/02/2022 00:00:00           NaN          NaN  Vehicle/Towed Trailer
# 1  02/02/2022 00:00:00           NaN          NaN  Vehicle/Towed Trailer
# 2  02/02/2022 00:00:00          18.0            M     Outside/Open Areas
# 3  02/02/2022 00:00:00          35.0            M  Vehicle/Towed Trailer
# 4  02/17/2022 00:00:00          29.0            F                Boating
#
#    EVENT_YEARMONTH
# 0           202202
# 1           202202
# 2           202202
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69477 entries, 0 to 69476
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     69477 non-null  int64
#  1   BEGIN_DAY           69477 non-null  int64
#  2   BEGIN_TIME          69477 non-null  int64
#  3   END_YEARMONTH       69477 non-null  int64
#  4   END_DAY             69477 non-null  int64
#  5   END_TIME            69477 non-null  int64
#  6   EPISODE_ID          69477 non-null  int64
#  7   EVENT_ID            69477 non-null  int64
#  8   STATE               69477 non-null  object
#  9   STATE_FIPS          69477 non-null  int64
#  10  YEAR                69477 non-null  int64
#  11  MONTH_NAME          69477 non-null  object
#  12  EVENT_TYPE          69477 non-null  object
#  13  CZ_TYPE             69477 non-null  object
#  14  CZ_FIPS             69477 non-null  int64
# ...

# %%
df1 = pd.read_csv('./StormEvents_locations_2022.csv')
df1.head()
# Out:
#    YEARMONTH  EPISODE_ID  EVENT_ID  LOCATION_INDEX  RANGE AZIMUTH  \
# 0     202210      173111   1051457               1   0.00       N
# 1     202210      173111   1053281               1   9.95      NW
# 2     202210      173122   1051505               1   1.08       W
# 3     202210      173123   1051506               1   0.81      NE
# 4     202210      173123   1051507               1   1.75     WNW
#
#           LOCATION  LATITUDE  LONGITUDE     LAT2      LON2
# 0         EDGEWOOD   35.0700  -106.2000   354200  10612000
# 1     MEXICAN SPGS   35.8753  -108.9632  3552518  10857792
# 2            NUCLA   38.2700  -108.5500  3816200  10833000
# 3            ELGIN   38.9880  -110.1390  3859280   1108340
# 4  SOLITUDE SIDING   38.9600  -110.0600  3857600   1103600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69477 entries, 0 to 69476
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     69477 non-null  int64
#  1   BEGIN_DAY           69477 non-null  int64
#  2   BEGIN_TIME          69477 non-null  int64
#  3   END_YEARMONTH       69477 non-null  int64
#  4   END_DAY             69477 non-null  int64
#  5   END_TIME            69477 non-null  int64
#  6   EPISODE_ID          69477 non-null  int64
#  7   EVENT_ID            69477 non-null  int64
#  8   STATE               69477 non-null  object
#  9   STATE_FIPS          69477 non-null  int64
#  10  YEAR                69477 non-null  int64
#  11  MONTH_NAME          69477 non-null  object
#  12  EVENT_TYPE          69477 non-null  object
#  13  CZ_TYPE             69477 non-null  object
#  14  CZ_FIPS             69477 non-null  int64
# ...

# %%
first_merge = pd.merge(df, df1, on="EVENT_ID", how='left')
first_merge.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202202         20        2118         202202       20      2218
# 1           202202         21         800         202202       22      1000
# 2           202202         22         200         202202       22       900
# 3           202202         18        1609         202202       18      1609
# 4           202202          2           0         202202        3         0
#
#    EPISODE_ID_x  EVENT_ID           STATE  STATE_FIPS  ...  YEARMONTH  \
# 0        165464    999902          NEVADA          32  ...        NaN
# 1        165465    999903          NEVADA          32  ...        NaN
# 2        165465    999904          NEVADA          32  ...        NaN
# 3        165611   1001181  ATLANTIC SOUTH          87  ...   202202.0
# 4        165668   1001527  AMERICAN SAMOA          97  ...   202202.0
#
#   EPISODE_ID_y LOCATION_INDEX RANGE  AZIMUTH     LOCATION LATITUDE LONGITUDE  \
# ...

# %%
second_merge = pd.merge(first_merge, df2, on='EVENT_ID', how='left')
second_merge.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202202         20        2118         202202       20      2218
# 1           202202         21         800         202202       22      1000
# 2           202202         22         200         202202       22       900
# 3           202202         18        1609         202202       18      1609
# 4           202202          2           0         202202        3         0
#
#    EPISODE_ID_x  EVENT_ID           STATE  STATE_FIPS  ...  FAT_YEARMONTH  \
# 0        165464    999902          NEVADA          32  ...            NaN
# 1        165465    999903          NEVADA          32  ...            NaN
# 2        165465    999904          NEVADA          32  ...            NaN
# 3        165611   1001181  ATLANTIC SOUTH          87  ...            NaN
# 4        165668   1001527  AMERICAN SAMOA          97  ...            NaN
#
# ...

# %%
df_2023d = pd.read_csv('./StormEvents_details_2023.csv')
df_2023d.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202302         26        2100         202302       26      2100
# 1           202302         26        2100         202302       26      2100
# 2           202302         26        2055         202302       26      2055
# 3           202302         26        2056         202302       26      2056
# 4           202303         26        2040         202303       26      2041
#
#    EPISODE_ID  EVENT_ID     STATE  STATE_FIPS  ...  END_RANGE END_AZIMUTH  \
# 0      177004   1076081  OKLAHOMA          40  ...        5.0           E
# 1      177004   1076082  OKLAHOMA          40  ...        4.0          NE
# 2      177004   1076077  OKLAHOMA          40  ...        4.0         ENE
# 3      177004   1076079  OKLAHOMA          40  ...        3.0         SSE
# 4      178958   1092342   GEORGIA          13  ...        3.0          SE
#
#      END_LOCATION BEGIN_LAT  BEGIN_LON END_LAT END_LON  \
# ...

# %%
df_2023d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27739 entries, 0 to 27738
# Data columns (total 51 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BEGIN_YEARMONTH     27739 non-null  int64
#  1   BEGIN_DAY           27739 non-null  int64
#  2   BEGIN_TIME          27739 non-null  int64
#  3   END_YEARMONTH       27739 non-null  int64
#  4   END_DAY             27739 non-null  int64
#  5   END_TIME            27739 non-null  int64
#  6   EPISODE_ID          27739 non-null  int64
#  7   EVENT_ID            27739 non-null  int64
#  8   STATE               27739 non-null  object
#  9   STATE_FIPS          27739 non-null  int64
#  10  YEAR                27739 non-null  int64
#  11  MONTH_NAME          27739 non-null  object
#  12  EVENT_TYPE          27739 non-null  object
#  13  CZ_TYPE             27739 non-null  object
#  14  CZ_FIPS             27739 non-null  int64
# ...

# %%
df_2023f = pd.read_csv('./StormEvents_fatalities_2023.csv')
df_2023f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FAT_YEARMONTH      237 non-null    int64
#  1   FAT_DAY            237 non-null    int64
#  2   FAT_TIME           237 non-null    int64
#  3   FATALITY_ID        237 non-null    int64
#  4   EVENT_ID           237 non-null    int64
#  5   FATALITY_TYPE      237 non-null    object
#  6   FATALITY_DATE      237 non-null    object
#  7   FATALITY_AGE       200 non-null    float64
#  8   FATALITY_SEX       212 non-null    object
#  9   FATALITY_LOCATION  237 non-null    object
#  10  EVENT_YEARMONTH    237 non-null    int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 20.5+ KB

# %%
df_2023l = pd.read_csv('./StormEvents_locations_2023.csv')
df_2023l.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21448 entries, 0 to 21447
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   YEARMONTH       21448 non-null  int64
#  1   EPISODE_ID      21448 non-null  int64
#  2   EVENT_ID        21448 non-null  int64
#  3   LOCATION_INDEX  21448 non-null  int64
#  4   RANGE           21448 non-null  float64
#  5   AZIMUTH         21448 non-null  object
#  6   LOCATION        21448 non-null  object
#  7   LATITUDE        21448 non-null  float64
#  8   LONGITUDE       21448 non-null  float64
#  9   LAT2            21448 non-null  int64
#  10  LON2            21448 non-null  int64
# dtypes: float64(3), int64(6), object(2)
# memory usage: 1.8+ MB

# %%
first_join = pd.merge(df_2023d, df_2023f, on="EVENT_ID", how='left')
first_join.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202302         26        2100         202302       26      2100
# 1           202302         26        2100         202302       26      2100
# 2           202302         26        2055         202302       26      2055
# 3           202302         26        2056         202302       26      2056
# 4           202303         26        2040         202303       26      2041
#
#    EPISODE_ID  EVENT_ID     STATE  STATE_FIPS  ...  FAT_YEARMONTH FAT_DAY  \
# 0      177004   1076081  OKLAHOMA          40  ...            NaN     NaN
# 1      177004   1076082  OKLAHOMA          40  ...            NaN     NaN
# 2      177004   1076077  OKLAHOMA          40  ...            NaN     NaN
# 3      177004   1076079  OKLAHOMA          40  ...            NaN     NaN
# 4      178958   1092342   GEORGIA          13  ...            NaN     NaN
#
# ...

# %%
second_join = pd.merge(first_join, df_2023l, on='EVENT_ID', how='left')
second_join.head()
# Out:
#    BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  END_TIME  \
# 0           202302         26        2100         202302       26      2100
# 1           202302         26        2100         202302       26      2100
# 2           202302         26        2055         202302       26      2055
# 3           202302         26        2056         202302       26      2056
# 4           202303         26        2040         202303       26      2041
#
#    EPISODE_ID_x  EVENT_ID     STATE  STATE_FIPS  ...  YEARMONTH EPISODE_ID_y  \
# 0        177004   1076081  OKLAHOMA          40  ...        NaN          NaN
# 1        177004   1076082  OKLAHOMA          40  ...        NaN          NaN
# 2        177004   1076077  OKLAHOMA          40  ...        NaN          NaN
# 3        177004   1076079  OKLAHOMA          40  ...        NaN          NaN
# 4        178958   1092342   GEORGIA          13  ...        NaN          NaN
#
# ...

# %%
final_df = pd.concat([second_merge, second_join])
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 120980 entries, 0 to 37375
# Data columns (total 71 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   BEGIN_YEARMONTH     120980 non-null  int64
#  1   BEGIN_DAY           120980 non-null  int64
#  2   BEGIN_TIME          120980 non-null  int64
#  3   END_YEARMONTH       120980 non-null  int64
#  4   END_DAY             120980 non-null  int64
#  5   END_TIME            120980 non-null  int64
#  6   EPISODE_ID_x        120980 non-null  int64
#  7   EVENT_ID            120980 non-null  int64
#  8   STATE               120980 non-null  object
#  9   STATE_FIPS          120980 non-null  int64
#  10  YEAR                120980 non-null  int64
#  11  MONTH_NAME          120980 non-null  object
#  12  EVENT_TYPE          120980 non-null  object
#  13  CZ_TYPE             120980 non-null  object
#  14  CZ_FIPS             120980 non-null  int64
# ...

# %%
final_df.to_csv("stormdata.csv", index=False)

# %%
pd.set_option('display.max_columns', None)

# %%
column_drop_df = final_df.drop(columns=['WFO','BEGIN_DAY', 'BEGIN_TIME', 'END_YEARMONTH',\
                                        'END_DAY','END_TIME','BEGIN_DATE_TIME','END_DATE_TIME',\
                                        'CZ_TYPE', 'CZ_FIPS', 'STATE_FIPS', 'CZ_TIMEZONE', 'MAGNITUDE',\
                                        'MAGNITUDE_TYPE','SOURCE', 'CATEGORY', 'TOR_OTHER_WFO', 'TOR_OTHER_CZ_STATE',\
                                        'TOR_OTHER_CZ_FIPS', 'TOR_OTHER_CZ_NAME', 'BEGIN_AZIMUTH', 'YEARMONTH',\
                                        'END_AZIMUTH', 'DATA_SOURCE', 'EPISODE_ID_y', 'LOCATION_INDEX', 'LOCATION',\
                                        'RANGE', 'AZIMUTH', 'LAT2', 'LON2', 'FAT_YEARMONTH', 'FAT_DAY', 'FAT_TIME',\
                                        'FATALITY_DATE', 'FATALITY_AGE','FATALITY_SEX', 'EVENT_YEARMONTH','FLOOD_CAUSE',\
                                       'TOR_F_SCALE','TOR_WIDTH','LATITUDE','LONGITUDE'])

# %%
column_drop_df['MONTH'] = column_drop_df['BEGIN_YEARMONTH']-(column_drop_df['YEAR']*100)
column_drop_df.head()
# Out:
#    BEGIN_YEARMONTH  EPISODE_ID_x  EVENT_ID           STATE  YEAR MONTH_NAME  \
# 0           202202        165464    999902          NEVADA  2022   February
# 1           202202        165465    999903          NEVADA  2022   February
# 2           202202        165465    999904          NEVADA  2022   February
# 3           202202        165611   1001181  ATLANTIC SOUTH  2022   February
# 4           202202        165668   1001527  AMERICAN SAMOA  2022   February
#
#    EVENT_TYPE                                       CZ_NAME  INJURIES_DIRECT  \
# 0   High Wind                             SOUTHEASTERN ELKO                0
# 1  Heavy Snow                           S LANDER & S EUREKA                0
# 2  Heavy Snow                                   N ELKO CNTY                0
# 3  Waterspout  FERNANDINA BEACH TO ST AUGUSTINE FL OUT 20NM                0
# 4  Heavy Rain                                       TUTUILA                0
#
# ...

# %%
column_drop_df = column_drop_df.drop(columns=['BEGIN_YEARMONTH'])
column_drop_df.head()
# Out:
#    EPISODE_ID_x  EVENT_ID           STATE  YEAR MONTH_NAME  EVENT_TYPE  \
# 0        165464    999902          NEVADA  2022   February   High Wind
# 1        165465    999903          NEVADA  2022   February  Heavy Snow
# 2        165465    999904          NEVADA  2022   February  Heavy Snow
# 3        165611   1001181  ATLANTIC SOUTH  2022   February  Waterspout
# 4        165668   1001527  AMERICAN SAMOA  2022   February  Heavy Rain
#
#                                         CZ_NAME  INJURIES_DIRECT  \
# 0                             SOUTHEASTERN ELKO                0
# 1                           S LANDER & S EUREKA                0
# 2                                   N ELKO CNTY                0
# 3  FERNANDINA BEACH TO ST AUGUSTINE FL OUT 20NM                0
# 4                                       TUTUILA                0
#
#    INJURIES_INDIRECT  DEATHS_DIRECT  DEATHS_INDIRECT DAMAGE_PROPERTY  \
# 0                  0              0                0           0.00K
# ...

# %%
column_drop_df.to_csv("cleaned_stormdata.csv", index=False)

# %%
#could extract just the month number from BEGIN_YEARMONTH
#drop any STATE rows that are not actually states
#Potentially drop the WFO,BEGIN/END_DATE_TIME, CZ_TYPE, CZ_FIPS, STATE_FIPS, CZ_TIMEZONE, MAGNITUDE,MAGNITUDE_TYPE,
#SOURCE, CATEGORY, TOR_OTHER_WFO, TOR_OTHER_CZ_STATE, TOR_OTHER_CZ_FIPS, TOR_OTHER_CZ_NAME, BEGIN_AZIMUTH, YEARMONTH,
#END_AZIMUTH, DATA_SOURCE, EPISODE_ID_y, LOCATION_INDEX, LOCATION, RANGE, AZIMUTH, LAT2, LON2, FAT_YEARMONTH, FAT_DAY, FAT_TIME,
#FATALITY_DATE, FATALITY_AGE,FATALITY_SEX, EVENT_YEARMONTH


#what to have in the dashboard to provide value:
    #put at least 3 different kinds of charts (even if simple bar, line, pie) - easy to look at and understand
    #don't include more than 7 visualizations - don't make it too busy
    #2-3 charts are a bit more complex (geomaps charts, histogram)
    #use simple titles
    #use filters in the charts

# %%
cleaned_df = column_drop_df.drop_duplicates(subset=['EVENT_ID'])
cleaned_df_reset = cleaned_df.reset_index()
del cleaned_df_reset['index']
cleaned_df_reset
# Out:
#        EPISODE_ID_x  EVENT_ID           STATE  YEAR MONTH_NAME  EVENT_TYPE  \
# 0            165464    999902          NEVADA  2022   February   High Wind
# 1            165465    999903          NEVADA  2022   February  Heavy Snow
# 2            165465    999904          NEVADA  2022   February  Heavy Snow
# 3            165611   1001181  ATLANTIC SOUTH  2022   February  Waterspout
# 4            165668   1001527  AMERICAN SAMOA  2022   February  Heavy Rain
# ...             ...       ...             ...   ...        ...         ...
# 97211        181053   1104956      WASHINGTON  2023        May        Hail
# 97212        181053   1104957      WASHINGTON  2023        May        Hail
# 97213        181053   1104958      WASHINGTON  2023        May       Flood
# 97214        181053   1104959      WASHINGTON  2023        May        Hail
# 97215        178818   1088453    SOUTH DAKOTA  2023        May        Hail
#
# ...

# %%
cleaned_df_reset.index.value_counts()
# Out:
# 0        1
# 64807    1
# 64816    1
# 64815    1
# 64814    1
#         ..
# 32403    1
# 32402    1
# 32401    1
# 32400    1
# 97215    1
# Length: 97216, dtype: int64

# %%
cleaned_df = cleaned_df_reset.dropna(subset=['BEGIN_LAT', 'BEGIN_LON'])
cleaned_df_reset = cleaned_df.reset_index()
del cleaned_df_reset['index']
cleaned_df_reset
# Out:
#        EPISODE_ID_x  EVENT_ID           STATE  YEAR MONTH_NAME  EVENT_TYPE  \
# 0            165611   1001181  ATLANTIC SOUTH  2022   February  Waterspout
# 1            165668   1001527  AMERICAN SAMOA  2022   February  Heavy Rain
# 2            165669   1001529  AMERICAN SAMOA  2022   February  Heavy Rain
# 3            168040   1034259       LOUISIANA  2022      March     Tornado
# 4            168040   1034260       LOUISIANA  2022      March     Tornado
# ...             ...       ...             ...   ...        ...         ...
# 49918        181053   1104956      WASHINGTON  2023        May        Hail
# 49919        181053   1104957      WASHINGTON  2023        May        Hail
# 49920        181053   1104958      WASHINGTON  2023        May       Flood
# 49921        181053   1104959      WASHINGTON  2023        May        Hail
# 49922        178818   1088453    SOUTH DAKOTA  2023        May        Hail
#
# ...

# %%
cleaned_df_reset.to_json('final_final_storm.json',orient='index')

# %%
final_dict = cleaned_df_reset.to_dict(orient='index')
final_dict
# Out:
# {0: {'EPISODE_ID_x': 165611,
#   'EVENT_ID': 1001181,
#   'STATE': 'ATLANTIC SOUTH',
#   'YEAR': 2022,
#   'MONTH_NAME': 'February',
#   'EVENT_TYPE': 'Waterspout',
#   'CZ_NAME': 'FERNANDINA BEACH TO ST AUGUSTINE FL OUT 20NM',
#   'INJURIES_DIRECT': 0,
#   'INJURIES_INDIRECT': 0,
#   'DEATHS_DIRECT': 0,
#   'DEATHS_INDIRECT': 0,
#   'DAMAGE_PROPERTY': '0.00K',
#   'DAMAGE_CROPS': '0.00K',
#   'TOR_LENGTH': nan,
#   'BEGIN_RANGE': 7.0,
#   'BEGIN_LOCATION': 'PONTE VEDRA',
#   'END_RANGE': 7.0,
#   'END_LOCATION': 'PONTE VEDRA',
#   'BEGIN_LAT': 30.05,
#   'BEGIN_LON': -81.17,
#   'END_LAT': 30.05,
#   'END_LON': -81.17,
#   'EPISODE_NARRATIVE': 'Pre-frontal showers and thunderstorms moved southward across the local Atlantic waters in the afternoon.',
#   'EVENT_NARRATIVE': 'A brief waterspout was observed offshore of South Ponte Vedra Beach. The location was approximated.',
#   'FATALITY_ID': nan,
#   'FATALITY_TYPE': nan,
#   'FATALITY_LOCATION': nan,
#   'MONTH': 2},
# ...

# %%
final_storm_df = pd.DataFrame(final_dict)
final_storm_df.to_json('final_storm.json', orient='index')

# %%
final_dict['names'] = []
final_dict.update({'names': ['ALABAMA',
 'ALASKA',
 'AMERICAN SAMOA',
 'ARIZONA',
 'ARKANSAS',
 'CALIFORNIA',
 'COLORADO',
 'CONNECTICUT',
 'DELAWARE',
 'DISTRICT OF COLUMBIA',
 'FLORIDA',
 'GEORGIA',
 'GUAM',
 'HAWAII',
 'IDAHO',
 'ILLINOIS',
 'INDIANA',
 'IOWA',
 'KANSAS',
 'KENTUCKY',
 'LOUISIANA',
 'MAINE',
 'MARYLAND',
 'MASSACHUSETTS',
 'MICHIGAN',
 'MINNESOTA',
 'MISSISSIPPI',
 'MISSOURI',
 'MONTANA',
 'NEBRASKA',
 'NEVADA',
 'NEW HAMPSHIRE',
 'NEW JERSEY',
 'NEW MEXICO',
 'NEW YORK',
 'NORTH CAROLINA',
 'NORTH DAKOTA',
 'OHIO',
 'OKLAHOMA',
 'OREGON',
 'PENNSYLVANIA',
 'PUERTO RICO',
 'RHODE ISLAND',
 'SOUTH CAROLINA',
 'SOUTH DAKOTA',
 'TENNESSEE',
 'TEXAS', 'UTAH', 'VERMONT', 'VIRGIN ISLANDS', 'VIRGINIA', 'WASHINGTON', 'WEST VIRGINIA', 'WISCONSIN',  'WYOMING']})
final_dict['names']

# %%
#import json
#with open('storm.json', 'w') as json_file:
   # json.dump(final_dict, json_file)

# %%
#import json
#import gzip

# Define the file names
#json_filename = 'storm.json'
#compressed_filename = 'storm.json.gz'

# Create the compressed JSON file
#with gzip.open(compressed_filename, 'wt') as compressed_file:
   # json.dump(final_dict, compressed_file)
